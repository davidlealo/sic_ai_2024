# %% [markdown]
# <a href="https://colab.research.google.com/github/davidlealo/sic_ai_2024/blob/main/007_proyecto/%5Bb%5Dmovierecommender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hola profe no si es esto a lo que se refería pero aquí tengo algunos csv y los uní JSJSJ

# %%
import numpy as np
import pandas as pd

# %%
dfIMDB = pd.read_csv("/content/IMDB-Movie-Data.csv")
dfIMDB.head(10)

# %%
dfIMDB

# %%
dfIMDB.isnull().sum()

# %%
dfIMDB.info()

# %%
# valores unicos de dfIMDB['Metascore']
dfIMDB['Metascore'].unique()

# %%
dfIMDB['Metascore'].mean() # Opción uno es fill con el mean
# Opción dos es eliminar la columna

# %%
dfMovies = pd.read_csv("/content/MoviesOnStreamingPlatforms.csv")
dfMovies.head(20)

# %%
dfMovies.tail(20)

# %%
dfMovies

# %%
dfMovies.isnull().sum()

# %%
dfMovies.info()

# %%
# Valores unicos para dfMovies['Age']
dfMovies['Age'].unique()

# %%
# print dfMovies['Age'] = nan
dfMovies[dfMovies['Age'].isnull()].head(20)

# %%
dfNetflix = pd.read_csv("/content/netflix_titles_nov_2019.csv")
dfNetflix.head(20)

# %%
dfNetflix.info()

# %%
dfNetflix.isnull().sum()

# %%
dfNetflix.rename(columns={'title': 'Title'}, inplace=True)

dfMerge = pd.merge(dfIMDB, dfNetflix, on='Title', how='inner')
dfMerge = pd.merge(dfMerge, dfMovies, on='Title', how='inner')

dfMerge

# %%
dfMerge.isnull().sum()

# %% [markdown]
# Salió mal xd (no tomar en cuenta, estaba juganding)

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# Cargar los datasets
dfIMDB = pd.read_csv('/content/IMDB-Movie-Data.csv')
dfMovies = pd.read_csv('/content/MoviesOnStreamingPlatforms.csv')
dfNetflix = pd.read_csv('/content/netflix_titles_nov_2019.csv')

# Renombrar columna en dfNetflix para hacer el merge
dfNetflix.rename(columns={'title': 'Title'}, inplace=True)

# Fusión de los datasets por la columna 'Title'
dfMerge = pd.merge(dfIMDB, dfNetflix, on='Title', how='inner')
dfFinal = pd.merge(dfMerge, dfMovies, on='Title', how='inner')

# Eliminar duplicados
dfFinal.drop_duplicates(inplace=True)

# Identificar columnas con valores nulos
null_values = dfFinal.isnull().sum() / len(dfFinal) * 100

# Imputación para columnas numéricas con la mediana
imputer_num = SimpleImputer(strategy='median')
dfFinal['Revenue (Millions)'] = imputer_num.fit_transform(dfFinal[['Revenue (Millions)']])
dfFinal['Metascore'] = imputer_num.fit_transform(dfFinal[['Metascore']])

# Codificación de la columna 'Age' con LabelEncoder en lugar de imputación
label_encoder = LabelEncoder()
dfFinal['Age'] = label_encoder.fit_transform(dfFinal['Age'])

# Codificación de la columna 'Type' con LabelEncoder (es binaria: Movie/TV Show)
dfFinal['Type'] = label_encoder.fit_transform(dfFinal['Type'])

# Transformación de la columna 'Genre' para One-Hot Encoding
dfFinal['Genre'] = dfFinal['Genre'].str.split(',')
dfFinal = dfFinal.explode('Genre')

# Aplicar One-Hot Encoding en la columna 'Genre'
dfFinal = pd.get_dummies(dfFinal, columns=['Genre'], prefix='Genre', drop_first=True)

# Resultado del preprocesamiento
dfFinal.head()

# %%
dfMovies.info()

# %%
# drop dfMovies Unnamed: 0, ID, Age, Type
dfMovies.drop(['Unnamed: 0', 'ID', 'Age', 'Type'], axis=1, inplace=True)

# %%
dfMovies

# %%
import os
import zipfile
import requests
import pandas as pd

# URL del dataset
url = "https://files.grouplens.org/datasets/movielens/ml-20m.zip"
zip_file = "ml-20m.zip"
extract_dir = "ml-20m"

# Descargar el dataset
if not os.path.exists(zip_file):
    print("Descargando dataset...")
    response = requests.get(url)
    with open(zip_file, 'wb') as f:
        f.write(response.content)
    print("Descarga completa.")

# Descomprimir el dataset
if not os.path.exists(extract_dir):
    print("Descomprimiendo dataset...")
    with zipfile.ZipFile(zip_file, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)
    print("Descompresión completa.")

# %%
movies = pd.read_csv("/content/ml-20m/ml-20m/movies.csv")
movies

# %%
rating = pd.read_csv("/content/ml-20m/ml-20m/ratings.csv")
rating

# %%
# merge movie y rating [movieID]
dfMerge = pd.merge(movies, rating, on='movieId', how='inner')
dfMerge

# %%
# Dividir la columna 'title' en dos nuevas columnas
dfMerge[['title', 'year']] = dfMerge['title'].str.extract(r'(.+?) \((\d{4})\)')

# Mostrar el DataFrame resultante
print(dfMerge)
# Out:
#           movieId                   title  \
# 0               1               Toy Story
# 1               1               Toy Story
# 2               1               Toy Story
# 3               1               Toy Story
# 4               1               Toy Story
# ...           ...                     ...
# 20000258   131254   Kein Bund für's Leben
# 20000259   131256  Feuer, Eis & Dosenbier
# 20000260   131258             The Pirates
# 20000261   131260            Rentun Ruusu
# 20000262   131262               Innocence
#
#                                                genres  userId  rating  \
# 0         Adventure|Animation|Children|Comedy|Fantasy       3     4.0
# 1         Adventure|Animation|Children|Comedy|Fantasy       6     5.0
# 2         Adventure|Animation|Children|Comedy|Fantasy       8     4.0
# 3         Adventure|Animation|Children|Comedy|Fantasy      10     4.0
# 4         Adventure|Animation|Children|Comedy|Fantasy      11     4.5
# ...

# %%
display(dfMerge.head(20))
# Out:
#     movieId      title                                       genres  userId  \
# 0         1  Toy Story  Adventure|Animation|Children|Comedy|Fantasy       3
# 1         1  Toy Story  Adventure|Animation|Children|Comedy|Fantasy       6
# 2         1  Toy Story  Adventure|Animation|Children|Comedy|Fantasy       8
# 3         1  Toy Story  Adventure|Animation|Children|Comedy|Fantasy      10
# 4         1  Toy Story  Adventure|Animation|Children|Comedy|Fantasy      11
# 5         1  Toy Story  Adventure|Animation|Children|Comedy|Fantasy      12
# 6         1  Toy Story  Adventure|Animation|Children|Comedy|Fantasy      13
# 7         1  Toy Story  Adventure|Animation|Children|Comedy|Fantasy      14
# 8         1  Toy Story  Adventure|Animation|Children|Comedy|Fantasy      16
# 9         1  Toy Story  Adventure|Animation|Children|Comedy|Fantasy      19
# 10        1  Toy Story  Adventure|Animation|Children|Comedy|Fantasy      22
# ...

# %%
# en dfMovies cambiar nombre de variables a minuscula
dfMovies.columns = dfMovies.columns.str.lower()

# %%
df_combined = pd.merge(dfMovies, dfMerge, left_on=['title'], right_on=['title'], how='left')

# %%
df_combined
# Out:
#                                             title  year_x rotten tomatoes  \
# 0                                    The Irishman    2019          98/100
# 1                                          Dangal    2016          97/100
# 2        David Attenborough: A Life on Our Planet    2020          95/100
# 3               Lagaan: Once Upon a Time in India    2001          94/100
# 4               Lagaan: Once Upon a Time in India    2001          94/100
# ...                                           ...     ...             ...
# 3058923                        Most Wanted Sharks    2020          14/100
# 3058924             Doc McStuffins: The Doc Is In    2020          13/100
# 3058925                     Ultimate Viking Sword    2019          13/100
# 3058926           Hunt for the Abominable Snowman    2011          10/100
# 3058927       Women of Impact: Changing the World    2019          10/100
#
#          netflix  hulu  prime video  disney+  movieId  \
# ...

# %%
# aliminar todos los valores NaN de df_combined
df_combined = df_combined.dropna()

# %%
df_combined.head(20)
# Out:
#                                 title  year_x rotten tomatoes  netflix  hulu  \
# 3   Lagaan: Once Upon a Time in India    2001          94/100        1     0
# 4   Lagaan: Once Upon a Time in India    2001          94/100        1     0
# 5   Lagaan: Once Upon a Time in India    2001          94/100        1     0
# 6   Lagaan: Once Upon a Time in India    2001          94/100        1     0
# 7   Lagaan: Once Upon a Time in India    2001          94/100        1     0
# 8   Lagaan: Once Upon a Time in India    2001          94/100        1     0
# 9   Lagaan: Once Upon a Time in India    2001          94/100        1     0
# 10  Lagaan: Once Upon a Time in India    2001          94/100        1     0
# 11  Lagaan: Once Upon a Time in India    2001          94/100        1     0
# 12  Lagaan: Once Upon a Time in India    2001          94/100        1     0
# 13  Lagaan: Once Upon a Time in India    2001          94/100        1     0
# ...

# %%
# drop timestamp	year_y
df_combined.drop(['timestamp', 'year_y'], axis=1, inplace=True)
# Out:
# <ipython-input-37-0bb8a38263d9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_combined.drop(['timestamp', 'year_y'], axis=1, inplace=True)

# %%
df_combined
# Out:
#                                         title  year_x rotten tomatoes  \
# 3           Lagaan: Once Upon a Time in India    2001          94/100
# 4           Lagaan: Once Upon a Time in India    2001          94/100
# 5           Lagaan: Once Upon a Time in India    2001          94/100
# 6           Lagaan: Once Upon a Time in India    2001          94/100
# 7           Lagaan: Once Upon a Time in India    2001          94/100
# ...                                       ...     ...             ...
# 3058752                       Walt & El Grupo    2008          47/100
# 3058753                       Walt & El Grupo    2008          47/100
# 3058786  The Adventures of André and Wally B.    1984          45/100
# 3058787  The Adventures of André and Wally B.    1984          45/100
# 3058788  The Adventures of André and Wally B.    1984          45/100
#
#          netflix  hulu  prime video  disney+   movieId  \
# 3              1     0            0        0    6776.0
# ...

# %%
# valores unicos para df combined rating
df_combined['rating'].unique()
# Out:
# array([4.5, 5. , 4. , 3.5, 2.5, 3. , 2. , 1. , 0.5, 1.5])

# %%
# !pip install scikit-surprise
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 3.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.4-cp310-cp310-linux_x86_64.whl size=2357278 sha256=ec68df07af07d7bd266dc78e09dac0da5fc67968a7217238e8c1355f5b3e25c5
#   Stored in directory: /root/.cache/pip/wheels/4b/3f/df/6acbf0a40397d9bf3ff97f582cc22fb9ce66adde75bc71fd54
# Successfully built scikit-surprise
# ...

# %%
import os
import urllib.request
import zipfile
from surprise import KNNBasic, Dataset, Reader
from surprise import accuracy
from surprise.model_selection import train_test_split
from collections import defaultdict
import pandas as pd

# Crear un diccionario para mapear id de película a título
movie_id_to_title = dict(zip(df_combined['movieId'], df_combined['title']))

reader = Reader(rating_scale=(0.5, 5))  # Ajusta el rango de calificación si es diferente
data = Dataset.load_from_df(df_combined[['userId', 'title', 'rating']], reader)

# Dividir el dataset en conjunto de entrenamiento y prueba
trainset, testset = train_test_split(data, test_size=.25)

# Crear el algoritmo KNNBasic
modelo = KNNBasic(k=40, sim_options={'name': 'cosine', 'user_based': True})

# Entrenar el algoritmo con el conjunto de entrenamiento
modelo.fit(trainset)

# Hacer predicciones en el conjunto de prueba
predictions = modelo.test(testset)

# Calcular el RMSE (Root Mean Squared Error)
rmse = accuracy.rmse(predictions)
print(f"RMSE: {rmse}")

# Función para obtener las top N recomendaciones
def get_top_n(predictions, n=5):
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Ordenar las predicciones para cada usuario y obtener las top n
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return dict(top_n)

# Obtener las top 5 recomendaciones para todos los usuarios
top_n = get_top_n(predictions, n=5)

# Mostrar las top 5 recomendaciones para el usuario 1
print("\nTop 5 recomendaciones para el usuario 1:")
for iid, rating in top_n['1']:
    print(f"Película: {movie_id_to_title[int(iid)]}, Calificación estimada: {rating:.2f}")

# Mostrar todas las predicciones para el usuario 1
print("\nTodas las predicciones para el usuario 1:")
user_1_predictions = [pred for pred in predictions if pred.uid == '1']
for prediction in sorted(user_1_predictions, key=lambda x: x.est, reverse=True)[:10]:
    print(f"Película: {movie_id_to_title[int(prediction.iid)]}, "
          f"Calificación estimada: {prediction.est:.2f}")
