# %% [markdown]
# <a href="https://colab.research.google.com/github/XaxavierJS/sic_ai_2024/blob/main/subir.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame( {"Nombre": ["Javier Retamal", "Eva Ponce", "Kiara Villaroel", "Barbara Oyarzun"],
                   "Edad": [19, 12, 34, 99]} )

df
# Out:
#             Nombre  Edad
# 0   Javier Retamal    19
# 1        Eva Ponce    12
# 2  Kiara Villaroel    34
# 3  Barbara Oyarzun    99

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df["Edad"])
# Out:
# pandas.core.series.Series

# %%
df = pd.read_csv("data_Iris.csv")
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
dfMineduc = pd.read_csv("20240507_Asistencia_ABRIL_2023_20240506_WEB.csv", sep = ";")
dfMineduc.describe()
# Out:
#            AGNO  MES_ESCOLAR            RBD        DGV_RBD    COD_REG_RBD  \
# count  132063.0     132063.0  132063.000000  132063.000000  132063.000000
# mean     2024.0          4.0     207.988642       4.284523       4.484738
# std         0.0          0.0     116.734957       2.956657       5.314649
# min      2024.0          4.0       1.000000       0.000000       1.000000
# 25%      2024.0          4.0     112.000000       2.000000       2.000000
# 50%      2024.0          4.0     227.000000       4.000000       2.000000
# 75%      2024.0          4.0     304.000000       7.000000       2.000000
# max      2024.0          4.0     396.000000       9.000000      15.000000
#
#          COD_PRO_RBD    COD_COM_RBD  COD_DEPROV_RBD      RURAL_RBD  \
# count  132063.000000  132063.000000   132063.000000  132063.000000
# mean       46.242286    4625.392441       46.022451       0.062114
# std        52.961840    5296.108945       53.065942       0.241364
# ...

# %%
dfMineduc.columns
# Out:
# Index(['AGNO', 'MES_ESCOLAR', 'RBD', 'DGV_RBD', 'NOM_RBD', 'COD_REG_RBD',
#        'NOM_REG_RBD_A', 'COD_PRO_RBD', 'COD_COM_RBD', 'NOM_COM_RBD',
#        'COD_DEPROV_RBD', 'NOM_DEPROV_RBD', 'RURAL_RBD', 'COD_DEPE',
#        'COD_DEPE2', 'COD_ENSE', 'COD_ENSE2', 'COD_GRADO', 'LET_CUR', 'MRUN',
#        'GEN_ALU', 'FEC_NAC_ALU', 'COD_COM_ALU', 'NOM_COM_ALU',
#        'DIAS_ASISTIDOS', 'DIAS_TRABAJADOS', 'ASIS_PROMEDIO'],
#       dtype='object')

# %%
dfMineduc["NOM_REG_RBD_A"].unique()
# Out:
# array(['AYP', 'TPCA', 'ANTOF', 'ATCMA'], dtype=object)

# %%
dfMineduc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132063 entries, 0 to 132062
# Data columns (total 27 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   AGNO             132063 non-null  int64
#  1   MES_ESCOLAR      132063 non-null  int64
#  2   RBD              132063 non-null  int64
#  3   DGV_RBD          132063 non-null  int64
#  4   NOM_RBD          132063 non-null  object
#  5   COD_REG_RBD      132063 non-null  int64
#  6   NOM_REG_RBD_A    132063 non-null  object
#  7   COD_PRO_RBD      132063 non-null  int64
#  8   COD_COM_RBD      132063 non-null  int64
#  9   NOM_COM_RBD      132063 non-null  object
#  10  COD_DEPROV_RBD   132063 non-null  int64
#  11  NOM_DEPROV_RBD   132063 non-null  object
#  12  RURAL_RBD        132063 non-null  int64
#  13  COD_DEPE         132063 non-null  int64
#  14  COD_DEPE2        132063 non-null  int64
#  15  COD_ENSE         132063 non-null  int64
# ...

# %%
dfMineduc["ASIS_PROMEDIO"]
# Out:
# 0         0.954545
# 1         1.000000
# 2         0.000000
# 3         0.636364
# 4         0.000000
#             ...
# 132058    1.000000
# 132059    1.000000
# 132060    0.954545
# 132061    1.000000
# 132062         NaN
# Name: ASIS_PROMEDIO, Length: 132063, dtype: float64

# %%
# Cambiar , en por . en dfMineduc["ASIS_PROMEDIO"]
dfMineduc["ASIS_PROMEDIO"] = dfMineduc["ASIS_PROMEDIO"].str.replace(",", ".")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-2f12985023cf> in <cell line: 2>()
#       1 # Cambiar , en por . en dfMineduc["ASIS_PROMEDIO"]
# ----> 2 dfMineduc["ASIS_PROMEDIO"] = dfMineduc["ASIS_PROMEDIO"].str.replace(",", ".")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
# ...

# %%
dfMineduc["ASIS_PROMEDIO"] = dfMineduc["ASIS_PROMEDIO"].astype(float)
dfMineduc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132063 entries, 0 to 132062
# Data columns (total 27 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   AGNO             132063 non-null  int64
#  1   MES_ESCOLAR      132063 non-null  int64
#  2   RBD              132063 non-null  int64
#  3   DGV_RBD          132063 non-null  int64
#  4   NOM_RBD          132063 non-null  object
#  5   COD_REG_RBD      132063 non-null  int64
#  6   NOM_REG_RBD_A    132063 non-null  object
#  7   COD_PRO_RBD      132063 non-null  int64
#  8   COD_COM_RBD      132063 non-null  int64
#  9   NOM_COM_RBD      132063 non-null  object
#  10  COD_DEPROV_RBD   132063 non-null  int64
#  11  NOM_DEPROV_RBD   132063 non-null  object
#  12  RURAL_RBD        132063 non-null  int64
#  13  COD_DEPE         132063 non-null  int64
#  14  COD_DEPE2        132063 non-null  int64
#  15  COD_ENSE         132063 non-null  int64
# ...
