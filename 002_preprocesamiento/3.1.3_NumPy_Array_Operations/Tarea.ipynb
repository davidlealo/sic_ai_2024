# %%
# !git clone https://github.com/XaxavierJS/sic_ai_2024
# %cd sic_ai_2024
# Out:
# Cloning into 'sic_ai_2024'...
# remote: Enumerating objects: 110, done.
# remote: Counting objects: 100% (110/110), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 110 (delta 51), reused 75 (delta 22), pack-reused 0
# Receiving objects: 100% (110/110), 2.54 MiB | 12.84 MiB/s, done.
# Resolving deltas: 100% (51/51), done.
# /content/sic_ai_2024/sic_ai_2024/sic_ai_2024/sic_ai_2024

# %%
# !git checkout -b prueba
# Out:
# Switched to a new branch 'prueba'

# %%
import numpy as np

# %%
array1 = np.array([1, 2, 3])
array2 = np.array([4, 5, 6])
array3 = np.array([7, 8, 9])

print(array1)
print("\n")
#Muestra las filas y columnas del array
print(array1.shape)
#Tamaño del array
print(array1.size)
#dimensiones array
print(array1.ndim)
# Out:
# [1 2 3]
#
#
# (3,)
# 3
# 1

# %%
#Suma cada celda
arraySuma = array1 + array2 + array3
print(arraySuma)

#Resta cada celda
arrayResta = array1 - array2 - array3
print(arrayResta)

#Multiplica cada
arrayMult = array1 * array2 * array3
print(arrayMult)

# el 1er array es la base, 2do array exponente
arrayExpone = array1 ** array2
print(arrayExpone)

#divide cada celda del array
arrayDiv = arrayMult / arraySuma
print(np.round(arrayDiv, 2))
# Out:
# [12 15 18]
# [-10 -11 -12]
# [ 28  80 162]
# [  1  32 729]
# [2.33 5.33 9.  ]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#ejemplo

arraySen = np.sin(array1)
print(arraySen)

arrayCos = np.cos(array1)
print(arrayCos)

arrayTan = np.tan(array1)
print(arrayTan)
# Out:
# [0.84147098 0.90929743 0.14112001]
# [ 0.54030231 -0.41614684 -0.9899925 ]
# [ 1.55740772 -2.18503986 -0.14254654]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
arrayMax = np.max(array1)
print(arrayMax)

arrayMin = np.min(array2)
print(arrayMin)
# Out:
# 3
# 4

# %%
# !git config --global user.email "javier.retamal.f@mail.pucv.cl"
# !git config --global user.name "Javier"

# %%
# !git remote -v
# Out:
# origin	https://github.com/XaxavierJS/sic_ai_2024 (fetch)
# origin	https://github.com/XaxavierJS/sic_ai_2024 (push)

# %%
# !git remote add origin https://github.com/XaxavierJS/sic_ai_2024

# %%
# !git add tarea.ipynb
# !git commit -m "Cambios NumPy_Array_Operations"
# Out:
# fatal: pathspec 'tarea.ipynb' did not match any files
# On branch prueba
# nothing to commit, working tree clean

# %%
# !git push prueba
# Out:
# fatal: 'prueba' does not appear to be a git repository
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.
