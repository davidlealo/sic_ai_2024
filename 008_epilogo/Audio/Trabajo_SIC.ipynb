# %%
import speech_recognition as sr

def real_time_subtitles():
    # Inicializamos el reconocedor
    recognizer = sr.Recognizer()

    # Usamos el micrófono como fuente
    with sr.Microphone() as source:
        print("Ajustando el ruido ambiental... Un momento.")
        recognizer.adjust_for_ambient_noise(source)
        print("¡Comienza a hablar!")

        # Abre un archivo para escribir los subtítulos en tiempo real
        with open("subtitulos.txt", "w") as f:
            try:
                while True:
                    # Escucha el audio con un tiempo de espera y límite de frase más largos
                    print("Escuchando...")
                    audio = recognizer.listen(
                        source, timeout=10, phrase_time_limit=30)

                    # Intenta reconocer el audio
                    try:
                        text = recognizer.recognize_google(
                            audio, language="es-ES")
                        print(f"Subtítulo: {text}")

                        # Escribe los subtítulos en el archivo de texto
                        f.write(f"{text}\n")
                        f.flush()  # Asegura que los datos se escriban inmediatamente en el archivo
                    except sr.UnknownValueError:
                        print("No se pudo entender el audio.")
                    except sr.RequestError as e:
                        print(
                            f"Error con el servicio de reconocimiento de voz; {e}")

            except KeyboardInterrupt:
                print("Deteniendo subtítulos en tiempo real.")


if __name__ == "__main__":
    real_time_subtitles()
# Out:
# Ajustando el ruido ambiental... Un momento.
# ¡Comienza a hablar!
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# Subtítulo: aló
# Escuchando...
# Subtítulo: Oh qué brígido
# Escuchando...
# Subtítulo: Wow qué chucha
# Escuchando...
# Subtítulo: Oh perdón eh chiquillo
# Escuchando...
# Subtítulo: que me funcionó el código que me
# Escuchando...
# Subtítulo: sí no Hola Fernanda la la heroína
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# Subtítulo: Jajaja
# Escuchando...
# Subtítulo: ahí se alcanza a ver
# Escuchando...
# Subtítulo: se me está escuchando con él o sea con el micrófono
# Escuchando...
# Subtítulo: eh No sé huevada eh Jajaja
# Escuchando...
# Subtítulo: huevada
# Escuchando...
# Subtítulo: el el latinizado
# Escuchando...
# Subtítulo: ya pero boludo Ya ahora está súper
# Escuchando...
# Subtítulo: sí
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# Subtítulo: eh qué tal
# Escuchando...
# Subtítulo: qué tablita
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# Subtítulo: Ah claro
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# Subtítulo: Mira a mí me tinca que con esta parte ya tenemos así como el el 80% de toda la cuestión
# Escuchando...
# Subtítulo: final esta parte que dice subtítulo como lo entrega por aquí lo por aquí estaba leyendo lo tiene
# Escuchando...
# Subtítulo: sí sí no es súper bueno Mira de hecho dije 80% y lo puso con el porcentaje si está súper bueno
# Escuchando...
# Subtítulo: bueno esta misma cosa
# Escuchando...
# Subtítulo: sí le quería dar las gracias
# Escuchando...
# Subtítulo: entonces pues
# Escuchando...
# Subtítulo: ya pero él está misma cosa Esto como que va guardando así de de a poquito
# Escuchando...
# Subtítulo: ando como en una en una matriz
# Escuchando...
# Subtítulo: está matriz pasar la uned será un Word a PDF
# Escuchando...
# Subtítulo: la misma cuestión como que la podríamos ahí meter
# Escuchando...
# Subtítulo: al como el Machine learning y ahí hacer la la minuto
# Escuchando...
# Subtítulo: Machine learning cacha la huevada
# Escuchando...
# Subtítulo: me meto Ah jajaja la huevada
# Escuchando...
# Subtítulo: Sí voy a ir a la parte de diseño porque en Sí este código ya está está perfecto hoy la la hueva era como
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# Subtítulo: no se pudo entender el audio
# Escuchando...
# Subtítulo: se lo estoy diciendo ahora
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# Subtítulo: no parece que tiene un timer que cada cierto tiempo va
# Escuchando...
# Subtítulo: que está aquí está porque hay más 10 segundos
# Escuchando...
# Subtítulo: pasan o sea no sé si son 10 segundos pero sí
# Escuchando...
# Subtítulo: si pasa cierto tiempo como que sigue buscando
# Escuchando...
# Subtítulo: es súper corto Sí también me quedo me dejó para la cagada sí son como cinco líneas y y de las cinco como que tres son de explicación
# Escuchando...
# Subtítulo: conocedor
# Escuchando...
# Subtítulo: o sea un micrófono Es este está librería en la en la mágica
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# Subtítulo: eh
# Escuchando...
# Subtítulo: a ver eh My name is Pablo
# Escuchando...
# Subtítulo: Hello
# Escuchando...
# Subtítulo: 10 berries
# Escuchando...
# Subtítulo: Ahí está está loca
# Escuchando...
# Subtítulo: Jajaja
# Escuchando...
# Subtítulo: Jajaja
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# Subtítulo: no está súper Bueno me estoy ahora
# Escuchando...
# Subtítulo: bueno esta cuestión ya
# Escuchando...
# Subtítulo: Jajaja
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# Subtítulo: a ver en japonés eh
# Escuchando...
# Subtítulo: konichiwa eh
# Escuchando...
# Subtítulo: hoy sí lo reconoce como
# Escuchando...
# Subtítulo: en romance Sí pero igual sí
# Escuchando...
# Subtítulo: en Roma
# Escuchando...
# Subtítulo: Jajaja
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# Subtítulo: y reconoce la risa también No si está súper buena está esta cosa
# Escuchando...
# Subtítulo: entonces voy a guardar el to
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# Subtítulo: Ah sí
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# Subtítulo: evaluación del
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# No se pudo entender el audio.
# Escuchando...
# Deteniendo subtítulos en tiempo real.
