# %% [markdown]
# <a href="https://colab.research.google.com/github/davidlealo/sic_ai_2024/blob/main/008_epilogo/Clase38_SIC_AI_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase 38: Mejora de sistema de recomendación

# %%
import numpy as np
import pandas as pd

# %%
# !wget https://raw.githubusercontent.com/davidlealo/sistema-recomendacion/refs/heads/main/MoviesOnStreamingPlatforms.csv
# Out:
# --2024-10-16 22:37:11--  https://raw.githubusercontent.com/davidlealo/sistema-recomendacion/refs/heads/main/MoviesOnStreamingPlatforms.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 506071 (494K) [text/plain]
# Saving to: ‘MoviesOnStreamingPlatforms.csv.1’
#
# MoviesOnStreamingPl 100%[===================>] 494.21K  --.-KB/s    in 0.02s
#
# 2024-10-16 22:37:11 (24.5 MB/s) - ‘MoviesOnStreamingPlatforms.csv.1’ saved [506071/506071]

# %%
dfMovies = pd.read_csv("MoviesOnStreamingPlatforms.csv")
dfMovies.head(20)
# Out:
#     Unnamed: 0  ID                                              Title  Year  \
# 0            0   1                                       The Irishman  2019
# 1            1   2                                             Dangal  2016
# 2            2   3           David Attenborough: A Life on Our Planet  2020
# 3            3   4                  Lagaan: Once Upon a Time in India  2001
# 4            4   5                                               Roma  2018
# 5            5   6                  To All the Boys I've Loved Before  2018
# 6            6   7                                 The Social Dilemma  2020
# 7            7   8                                               Okja  2017
# 8            8   9                       The Ballad of Buster Scruggs  2018
# 9            9  10                         The Trial of the Chicago 7  2020
# 10          10  11                                         Article 15  2019
# 11          11  12  Jim & Andy: The Great Beyond- Featuring a Very...  2017
# 12          12  13                                Dolemite Is My Name  2019
# 13          13  14                                           Mudbound  2017
# 14          14  15                                             Swades  2004
# 15          15  16                                               Fyre  2019
# 16          16  17                                     Miss Americana  2020
# 17          17  18                                            Virunga  2014
# 18          18  19                                       Black Friday  2004
# 19          19  20                                             Talvar  2015
#
#     Age Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type
# 0   18+          98/100        1     0            0        0     0
# 1    7+          97/100        1     0            0        0     0
# 2    7+          95/100        1     0            0        0     0
# 3    7+          94/100        1     0            0        0     0
# 4   18+          94/100        1     0            0        0     0
# 5   13+          94/100        1     0            0        0     0
# 6   13+          93/100        1     0            0        0     0
# 7   13+          92/100        1     0            0        0     0
# 8   16+          92/100        1     0            0        0     0
# 9   18+          92/100        1     0            0        0     0
# 10  18+          92/100        1     0            0        0     0
# 11  18+          92/100        1     0            0        0     0
# 12  18+          92/100        1     0            0        0     0
# 13  18+          91/100        1     0            0        0     0
# 14  all          91/100        1     0            0        0     0
# 15  18+          91/100        1     0            0        0     0
# 16  18+          90/100        1     0            0        0     0
# 17  16+          90/100        1     0            0        0     0
# 18  18+          90/100        1     0            0        0     0
# 19   7+          90/100        1     0            0        0     0

# %%
dfMovies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9515 entries, 0 to 9514
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       9515 non-null   int64
#  1   ID               9515 non-null   int64
#  2   Title            9515 non-null   object
#  3   Year             9515 non-null   int64
#  4   Age              5338 non-null   object
#  5   Rotten Tomatoes  9508 non-null   object
#  6   Netflix          9515 non-null   int64
#  7   Hulu             9515 non-null   int64
#  8   Prime Video      9515 non-null   int64
#  9   Disney+          9515 non-null   int64
#  10  Type             9515 non-null   int64
# dtypes: int64(8), object(3)
# memory usage: 817.8+ KB

# %%
dfMovies.isnull().sum()
# Out:
# Unnamed: 0            0
# ID                    0
# Title                 0
# Year                  0
# Age                4177
# Rotten Tomatoes       7
# Netflix               0
# Hulu                  0
# Prime Video           0
# Disney+               0
# Type                  0
# dtype: int64

# %%
# drop dfMovies Unnamed: 0, ID, Age, Type
dfMovies.drop(['Unnamed: 0', 'ID', 'Age', 'Type'], axis=1, inplace=True)

# %%
dfMovies
# Out:
#                                          Title  Year Rotten Tomatoes  Netflix  \
# 0                                 The Irishman  2019          98/100        1
# 1                                       Dangal  2016          97/100        1
# 2     David Attenborough: A Life on Our Planet  2020          95/100        1
# 3            Lagaan: Once Upon a Time in India  2001          94/100        1
# 4                                         Roma  2018          94/100        1
# ...                                        ...   ...             ...      ...
# 9510                        Most Wanted Sharks  2020          14/100        0
# 9511             Doc McStuffins: The Doc Is In  2020          13/100        0
# 9512                     Ultimate Viking Sword  2019          13/100        0
# 9513           Hunt for the Abominable Snowman  2011          10/100        0
# 9514       Women of Impact: Changing the World  2019          10/100        0
#
#       Hulu  Prime Video  Disney+
# 0        0            0        0
# 1        0            0        0
# 2        0            0        0
# 3        0            0        0
# 4        0            0        0
# ...    ...          ...      ...
# 9510     0            0        1
# 9511     0            0        1
# 9512     0            0        1
# 9513     0            0        1
# 9514     0            0        1
#
# [9515 rows x 7 columns]

# %%
import os
import zipfile
import requests
import pandas as pd

# URL del dataset
url = "https://files.grouplens.org/datasets/movielens/ml-20m.zip"
zip_file = "ml-20m.zip"
extract_dir = "ml-20m"

# Descargar el dataset
if not os.path.exists(zip_file):
    print("Descargando dataset...")
    response = requests.get(url)
    with open(zip_file, 'wb') as f:
        f.write(response.content)
    print("Descarga completa.")

# Descomprimir el dataset
if not os.path.exists(extract_dir):
    print("Descomprimiendo dataset...")
    with zipfile.ZipFile(zip_file, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)
    print("Descompresión completa.")

# %%
movies = pd.read_csv("ml-20m/ml-20m/movies.csv")
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 27273                                       Comedy
# 27274                                       Comedy
# 27275                                    Adventure
# 27276                           (no genres listed)
# 27277                     Adventure|Fantasy|Horror
#
# [27278 rows x 3 columns]

# %%
rating = pd.read_csv("ml-20m/ml-20m/ratings.csv")
rating
# Out:
#           userId  movieId  rating   timestamp
# 0              1        2     3.5  1112486027
# 1              1       29     3.5  1112484676
# 2              1       32     3.5  1112484819
# 3              1       47     3.5  1112484727
# 4              1       50     3.5  1112484580
# ...          ...      ...     ...         ...
# 20000258  138493    68954     4.5  1258126920
# 20000259  138493    69526     4.5  1259865108
# 20000260  138493    69644     3.0  1260209457
# 20000261  138493    70286     5.0  1258126944
# 20000262  138493    71619     2.5  1255811136
#
# [20000263 rows x 4 columns]

# %%
# merge movie y rating [movieID]
dfMerge = pd.merge(movies, rating, on='movieId', how='inner')
dfMerge
# Out:
#           movieId                          title  \
# 0               1               Toy Story (1995)
# 1               1               Toy Story (1995)
# 2               1               Toy Story (1995)
# 3               1               Toy Story (1995)
# 4               1               Toy Story (1995)
# ...           ...                            ...
# 20000258   131254   Kein Bund für's Leben (2007)
# 20000259   131256  Feuer, Eis & Dosenbier (2002)
# 20000260   131258             The Pirates (2014)
# 20000261   131260            Rentun Ruusu (2001)
# 20000262   131262               Innocence (2014)
#
#                                                genres  userId  rating  \
# 0         Adventure|Animation|Children|Comedy|Fantasy       3     4.0
# 1         Adventure|Animation|Children|Comedy|Fantasy       6     5.0
# 2         Adventure|Animation|Children|Comedy|Fantasy       8     4.0
# 3         Adventure|Animation|Children|Comedy|Fantasy      10     4.0
# 4         Adventure|Animation|Children|Comedy|Fantasy      11     4.5
# ...                                               ...     ...     ...
# 20000258                                       Comedy   79570     4.0
# 20000259                                       Comedy   79570     4.0
# 20000260                                    Adventure   28906     2.5
# 20000261                           (no genres listed)   65409     3.0
# 20000262                     Adventure|Fantasy|Horror  133047     4.0
#
#            timestamp
# 0          944919407
# 1          858275452
# 2          833981871
# 3          943497887
# 4         1230858821
# ...              ...
# 20000258  1427743979
# 20000259  1427744888
# 20000260  1427745392
# 20000261  1427745466
# 20000262  1427747966
#
# [20000263 rows x 6 columns]

# %%
# Dividir la columna 'title' en dos nuevas columnas
dfMerge[['title', 'year']] = dfMerge['title'].str.extract(r'(.+?) \((\d{4})\)')

# Mostrar el DataFrame resultante
print(dfMerge)
# Out:
#           movieId                   title  \
# 0               1               Toy Story
# 1               1               Toy Story
# 2               1               Toy Story
# 3               1               Toy Story
# 4               1               Toy Story
# ...           ...                     ...
# 20000258   131254   Kein Bund für's Leben
# 20000259   131256  Feuer, Eis & Dosenbier
# 20000260   131258             The Pirates
# 20000261   131260            Rentun Ruusu
# 20000262   131262               Innocence
#
#                                                genres  userId  rating  \
# 0         Adventure|Animation|Children|Comedy|Fantasy       3     4.0
# 1         Adventure|Animation|Children|Comedy|Fantasy       6     5.0
# 2         Adventure|Animation|Children|Comedy|Fantasy       8     4.0
# 3         Adventure|Animation|Children|Comedy|Fantasy      10     4.0
# 4         Adventure|Animation|Children|Comedy|Fantasy      11     4.5
# ...                                               ...     ...     ...
# 20000258                                       Comedy   79570     4.0
# 20000259                                       Comedy   79570     4.0
# 20000260                                    Adventure   28906     2.5
# 20000261                           (no genres listed)   65409     3.0
# 20000262                     Adventure|Fantasy|Horror  133047     4.0
#
#            timestamp  year
# 0          944919407  1995
# 1          858275452  1995
# 2          833981871  1995
# 3          943497887  1995
# 4         1230858821  1995
# ...              ...   ...
# 20000258  1427743979  2007
# 20000259  1427744888  2002
# 20000260  1427745392  2014
# 20000261  1427745466  2001
# 20000262  1427747966  2014
#
# [20000263 rows x 7 columns]

# %%
display(dfMerge)
# Out:
#           movieId                   title  \
# 0               1               Toy Story
# 1               1               Toy Story
# 2               1               Toy Story
# 3               1               Toy Story
# 4               1               Toy Story
# ...           ...                     ...
# 20000258   131254   Kein Bund für's Leben
# 20000259   131256  Feuer, Eis & Dosenbier
# 20000260   131258             The Pirates
# 20000261   131260            Rentun Ruusu
# 20000262   131262               Innocence
#
#                                                genres  userId  rating  \
# 0         Adventure|Animation|Children|Comedy|Fantasy       3     4.0
# 1         Adventure|Animation|Children|Comedy|Fantasy       6     5.0
# 2         Adventure|Animation|Children|Comedy|Fantasy       8     4.0
# 3         Adventure|Animation|Children|Comedy|Fantasy      10     4.0
# 4         Adventure|Animation|Children|Comedy|Fantasy      11     4.5
# ...                                               ...     ...     ...
# 20000258                                       Comedy   79570     4.0
# 20000259                                       Comedy   79570     4.0
# 20000260                                    Adventure   28906     2.5
# 20000261                           (no genres listed)   65409     3.0
# 20000262                     Adventure|Fantasy|Horror  133047     4.0
#
#            timestamp  year
# 0          944919407  1995
# 1          858275452  1995
# 2          833981871  1995
# 3          943497887  1995
# 4         1230858821  1995
# ...              ...   ...
# 20000258  1427743979  2007
# 20000259  1427744888  2002
# 20000260  1427745392  2014
# 20000261  1427745466  2001
# 20000262  1427747966  2014
#
# [20000263 rows x 7 columns]

# %%
# en dfMovies cambiar nombre de variables a minuscula
dfMovies.columns = dfMovies.columns.str.lower()
dfMovies
# Out:
#                                          title  year rotten tomatoes  netflix  \
# 0                                 The Irishman  2019          98/100        1
# 1                                       Dangal  2016          97/100        1
# 2     David Attenborough: A Life on Our Planet  2020          95/100        1
# 3            Lagaan: Once Upon a Time in India  2001          94/100        1
# 4                                         Roma  2018          94/100        1
# ...                                        ...   ...             ...      ...
# 9510                        Most Wanted Sharks  2020          14/100        0
# 9511             Doc McStuffins: The Doc Is In  2020          13/100        0
# 9512                     Ultimate Viking Sword  2019          13/100        0
# 9513           Hunt for the Abominable Snowman  2011          10/100        0
# 9514       Women of Impact: Changing the World  2019          10/100        0
#
#       hulu  prime video  disney+
# 0        0            0        0
# 1        0            0        0
# 2        0            0        0
# 3        0            0        0
# 4        0            0        0
# ...    ...          ...      ...
# 9510     0            0        1
# 9511     0            0        1
# 9512     0            0        1
# 9513     0            0        1
# 9514     0            0        1
#
# [9515 rows x 7 columns]

# %%
df_combined = pd.merge(dfMovies, dfMerge, left_on=['title'], right_on=['title'], how='left')
display(df_combined)
# Out:
#                                             title  year_x rotten tomatoes  \
# 0                                    The Irishman    2019          98/100
# 1                                          Dangal    2016          97/100
# 2        David Attenborough: A Life on Our Planet    2020          95/100
# 3               Lagaan: Once Upon a Time in India    2001          94/100
# 4               Lagaan: Once Upon a Time in India    2001          94/100
# ...                                           ...     ...             ...
# 3058923                        Most Wanted Sharks    2020          14/100
# 3058924             Doc McStuffins: The Doc Is In    2020          13/100
# 3058925                     Ultimate Viking Sword    2019          13/100
# 3058926           Hunt for the Abominable Snowman    2011          10/100
# 3058927       Women of Impact: Changing the World    2019          10/100
#
#          netflix  hulu  prime video  disney+  movieId  \
# 0              1     0            0        0      NaN
# 1              1     0            0        0      NaN
# 2              1     0            0        0      NaN
# 3              1     0            0        0   6776.0
# 4              1     0            0        0   6776.0
# ...          ...   ...          ...      ...      ...
# 3058923        0     0            0        1      NaN
# 3058924        0     0            0        1      NaN
# 3058925        0     0            0        1      NaN
# 3058926        0     0            0        1      NaN
# 3058927        0     0            0        1      NaN
#
#                                genres  userId  rating     timestamp year_y
# 0                                 NaN     NaN     NaN           NaN    NaN
# 1                                 NaN     NaN     NaN           NaN    NaN
# 2                                 NaN     NaN     NaN           NaN    NaN
# 3        Comedy|Drama|Musical|Romance    14.0     4.5  1.225311e+09   2001
# 4        Comedy|Drama|Musical|Romance   176.0     5.0  1.426775e+09   2001
# ...                               ...     ...     ...           ...    ...
# 3058923                           NaN     NaN     NaN           NaN    NaN
# 3058924                           NaN     NaN     NaN           NaN    NaN
# 3058925                           NaN     NaN     NaN           NaN    NaN
# 3058926                           NaN     NaN     NaN           NaN    NaN
# 3058927                           NaN     NaN     NaN           NaN    NaN
#
# [3058928 rows x 13 columns]

# %%
# Eliminar todos los valores NaN de df_combined
df_combined = df_combined.dropna()

# %%
df_combined
# Out:
#                                         title  year_x rotten tomatoes  \
# 3           Lagaan: Once Upon a Time in India    2001          94/100
# 4           Lagaan: Once Upon a Time in India    2001          94/100
# 5           Lagaan: Once Upon a Time in India    2001          94/100
# 6           Lagaan: Once Upon a Time in India    2001          94/100
# 7           Lagaan: Once Upon a Time in India    2001          94/100
# ...                                       ...     ...             ...
# 3058752                       Walt & El Grupo    2008          47/100
# 3058753                       Walt & El Grupo    2008          47/100
# 3058786  The Adventures of André and Wally B.    1984          45/100
# 3058787  The Adventures of André and Wally B.    1984          45/100
# 3058788  The Adventures of André and Wally B.    1984          45/100
#
#          netflix  hulu  prime video  disney+   movieId  \
# 3              1     0            0        0    6776.0
# 4              1     0            0        0    6776.0
# 5              1     0            0        0    6776.0
# 6              1     0            0        0    6776.0
# 7              1     0            0        0    6776.0
# ...          ...   ...          ...      ...       ...
# 3058752        0     0            0        1   83978.0
# 3058753        0     0            0        1   83978.0
# 3058786        0     0            0        1  126405.0
# 3058787        0     0            0        1  126405.0
# 3058788        0     0            0        1  126405.0
#
#                                genres    userId  rating     timestamp year_y
# 3        Comedy|Drama|Musical|Romance      14.0     4.5  1.225311e+09   2001
# 4        Comedy|Drama|Musical|Romance     176.0     5.0  1.426775e+09   2001
# 5        Comedy|Drama|Musical|Romance     206.0     4.0  1.117061e+09   2001
# 6        Comedy|Drama|Musical|Romance     266.0     3.5  1.311928e+09   2001
# 7        Comedy|Drama|Musical|Romance     306.0     2.5  1.084898e+09   2001
# ...                               ...       ...     ...           ...    ...
# 3058752                   Documentary   26867.0     2.0  1.301398e+09   2008
# 3058753                   Documentary  121535.0     2.5  1.301816e+09   2008
# 3058786                     Animation    1678.0     3.0  1.422291e+09   1984
# 3058787                     Animation   61678.0     0.5  1.422145e+09   1984
# 3058788                     Animation   65687.0     0.5  1.423035e+09   1984
#
# [3051236 rows x 13 columns]

# %%
# drop timestamp	year_y
df_combined.drop(['timestamp', 'year_y'], axis=1, inplace=True)

# %%
df_combined
# Out:
#                                         title  year_x rotten tomatoes  \
# 3           Lagaan: Once Upon a Time in India    2001          94/100
# 4           Lagaan: Once Upon a Time in India    2001          94/100
# 5           Lagaan: Once Upon a Time in India    2001          94/100
# 6           Lagaan: Once Upon a Time in India    2001          94/100
# 7           Lagaan: Once Upon a Time in India    2001          94/100
# ...                                       ...     ...             ...
# 3058752                       Walt & El Grupo    2008          47/100
# 3058753                       Walt & El Grupo    2008          47/100
# 3058786  The Adventures of André and Wally B.    1984          45/100
# 3058787  The Adventures of André and Wally B.    1984          45/100
# 3058788  The Adventures of André and Wally B.    1984          45/100
#
#          netflix  hulu  prime video  disney+   movieId  \
# 3              1     0            0        0    6776.0
# 4              1     0            0        0    6776.0
# 5              1     0            0        0    6776.0
# 6              1     0            0        0    6776.0
# 7              1     0            0        0    6776.0
# ...          ...   ...          ...      ...       ...
# 3058752        0     0            0        1   83978.0
# 3058753        0     0            0        1   83978.0
# 3058786        0     0            0        1  126405.0
# 3058787        0     0            0        1  126405.0
# 3058788        0     0            0        1  126405.0
#
#                                genres    userId  rating
# 3        Comedy|Drama|Musical|Romance      14.0     4.5
# 4        Comedy|Drama|Musical|Romance     176.0     5.0
# 5        Comedy|Drama|Musical|Romance     206.0     4.0
# 6        Comedy|Drama|Musical|Romance     266.0     3.5
# 7        Comedy|Drama|Musical|Romance     306.0     2.5
# ...                               ...       ...     ...
# 3058752                   Documentary   26867.0     2.0
# 3058753                   Documentary  121535.0     2.5
# 3058786                     Animation    1678.0     3.0
# 3058787                     Animation   61678.0     0.5
# 3058788                     Animation   65687.0     0.5
#
# [3051236 rows x 11 columns]

# %%
# valores unicos para df combined rating
df_combined['rating'].unique()
# Out:
# array([4.5, 5. , 4. , 3.5, 2.5, 3. , 2. , 1. , 0.5, 1.5])

# %%
# Export df_muestra to csv
df_combined.to_csv('df_combined.csv', index=False)

# %% [markdown]
# # Truco para trabajar esto en colab
# Resetear la ram porque el archivo anterior de más de 3 millones de observaciones consumía todos los recursos
#
# ```bash
# reset -f
# ```

# %%
# %reset -f

# %% [markdown]
# ### Instalar Surprise
# Librería especializada para generación de sistemas de recomendación [link](https://surpriselib.com/)

# %%
# !pip install scikit-surprise
# Out:
# Requirement already satisfied: scikit-surprise in /usr/local/lib/python3.10/dist-packages (1.1.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.13.1)

# %%
import os
import urllib.request
import zipfile
from surprise import KNNBasic, Dataset, Reader
from surprise import accuracy
from surprise.model_selection import train_test_split
from collections import defaultdict
import pandas as pd
import numpy as np

# %%
df_combined = pd.read_csv("df_combined.csv")
df_combined
# Out:
#                                         title  year_x rotten tomatoes  \
# 0           Lagaan: Once Upon a Time in India    2001          94/100
# 1           Lagaan: Once Upon a Time in India    2001          94/100
# 2           Lagaan: Once Upon a Time in India    2001          94/100
# 3           Lagaan: Once Upon a Time in India    2001          94/100
# 4           Lagaan: Once Upon a Time in India    2001          94/100
# ...                                       ...     ...             ...
# 3051231                       Walt & El Grupo    2008          47/100
# 3051232                       Walt & El Grupo    2008          47/100
# 3051233  The Adventures of André and Wally B.    1984          45/100
# 3051234  The Adventures of André and Wally B.    1984          45/100
# 3051235  The Adventures of André and Wally B.    1984          45/100
#
#          netflix  hulu  prime video  disney+   movieId  \
# 0              1     0            0        0    6776.0
# 1              1     0            0        0    6776.0
# 2              1     0            0        0    6776.0
# 3              1     0            0        0    6776.0
# 4              1     0            0        0    6776.0
# ...          ...   ...          ...      ...       ...
# 3051231        0     0            0        1   83978.0
# 3051232        0     0            0        1   83978.0
# 3051233        0     0            0        1  126405.0
# 3051234        0     0            0        1  126405.0
# 3051235        0     0            0        1  126405.0
#
#                                genres    userId  rating
# 0        Comedy|Drama|Musical|Romance      14.0     4.5
# 1        Comedy|Drama|Musical|Romance     176.0     5.0
# 2        Comedy|Drama|Musical|Romance     206.0     4.0
# 3        Comedy|Drama|Musical|Romance     266.0     3.5
# 4        Comedy|Drama|Musical|Romance     306.0     2.5
# ...                               ...       ...     ...
# 3051231                   Documentary   26867.0     2.0
# 3051232                   Documentary  121535.0     2.5
# 3051233                     Animation    1678.0     3.0
# 3051234                     Animation   61678.0     0.5
# 3051235                     Animation   65687.0     0.5
#
# [3051236 rows x 11 columns]

# %% [markdown]
# Crear una muestra aleatoria

# %%
from sklearn.utils.random import sample_without_replacement
# Define el tamaño de la población (total de filas)
n_population = df_combined.shape[0]  # 3051236
# Define el tamaño de la muestra
n_samples = 10000

# %%
# Obtén los índices aleatorios de la muestra sin reemplazo
indices_muestra = sample_without_replacement(n_population, n_samples, random_state=42)

# Crea un nuevo DataFrame con la muestra
df_muestra = df_combined.iloc[indices_muestra]

# Revisa la muestra resultante
print(df_muestra.shape)
# Out:
# (10000, 11)

# %%
# Crear un diccionario para mapear id de película a título
movie_id_to_title = dict(zip(df_muestra['movieId'], df_muestra['title']))

# %%
reader = Reader(rating_scale=(0.5, 5))  # Ajusta el rango de calificación si es diferente
data = Dataset.load_from_df(df_muestra[['userId', 'title', 'rating']], reader)

# Dividir el dataset en conjunto de entrenamiento y prueba
trainset, testset = train_test_split(data, test_size=.25)

# Crear el algoritmo KNNBasic
modelo = KNNBasic(k=40, sim_options={'name': 'cosine', 'user_based': True})

# Entrenar el algoritmo con el conjunto de entrenamiento
modelo.fit(trainset)

# Hacer predicciones en el conjunto de prueba
predictions = modelo.test(testset)

# Calcular el RMSE (Root Mean Squared Error)
rmse = accuracy.rmse(predictions)
print(f"RMSE: {rmse}")

# Función para obtener las top N recomendaciones
def get_top_n(predictions, n=5):
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Ordenar las predicciones para cada usuario y obtener las top n
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return dict(top_n)

# Obtener las top 5 recomendaciones para todos los usuarios
top_n = get_top_n(predictions, n=5)

# Mostrar las top 5 recomendaciones para el primer usuario disponible
first_user_id = list(top_n.keys())[0]  # Obtener el primer usuario disponible
print(f"\nTop 5 recomendaciones para el usuario {first_user_id}:")
for iid, rating in top_n[first_user_id]:
    # Si iid ya es un título, no hace falta convertirlo a entero
    pelicula = movie_id_to_title.get(int(iid), iid) if iid.isdigit() else iid
    print(f"Película: {pelicula}, Calificación estimada: {rating:.2f}")

# Mostrar todas las predicciones para el primer usuario disponible
print(f"\nTodas las predicciones para el usuario {first_user_id}:")
user_predictions = [pred for pred in predictions if pred.uid == first_user_id]
for prediction in sorted(user_predictions, key=lambda x: x.est, reverse=True)[:10]:
    pelicula = movie_id_to_title.get(int(prediction.iid), prediction.iid) if prediction.iid.isdigit() else prediction.iid
    print(f"Película: {pelicula}, Calificación estimada: {prediction.est:.2f}")
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0339
# RMSE: 1.033875429981775
#
# Top 5 recomendaciones para el usuario 96551.0:
# Película: Shrek, Calificación estimada: 3.50
#
# Todas las predicciones para el usuario 96551.0:
# Película: Shrek, Calificación estimada: 3.50

# %% [markdown]
# ## Aplicación listado de películas

# %%
import random
from IPython.display import Javascript, display, HTML
from google.colab.output import eval_js
import pandas as pd
import numpy as np
from surprise import Dataset, Reader, SVD

# Asumimos que df_muestra ya está cargado con las películas y ratings

# Convertir el DataFrame en el formato esperado por Surprise
reader = Reader(rating_scale=(0.5, 5))
data = Dataset.load_from_df(df_muestra[['userId', 'movieId', 'rating']], reader)

# Entrenar el modelo con Surprise
trainset = data.build_full_trainset()
modelo_svd = SVD()
modelo_svd.fit(trainset)

# Función para obtener recomendaciones de películas basadas en predicciones
def get_top_movies_for_user(user_id, last_liked_movie_id=None, n=5):
    # Obtener todas las películas que el usuario no ha visto
    unseen_movies = set(df_muestra['movieId']) - set(df_muestra[df_muestra['userId'] == user_id]['movieId'])

    # Predecir ratings para estas películas usando el modelo de Surprise
    predictions = [(movie_id, modelo_svd.predict(user_id, movie_id).est) for movie_id in unseen_movies]

    # Si hay una película que le gustó, filtrar por similitud
    if last_liked_movie_id is not None:
        # Filtrar las películas que tengan un score más cercano a la última película que le gustó
        similar_movies = [(movie_id, score) for movie_id, score in predictions if abs(score - modelo_svd.predict(user_id, last_liked_movie_id).est) < 0.1]
        predictions = similar_movies if similar_movies else predictions  # Si no hay similares, usar todas

    # Ordenar por rating predicho y devolver las top n
    return sorted(predictions, key=lambda x: x[1], reverse=True)[:n]

# Inicializar lista de películas recomendadas para un usuario aleatorio
def inicializar_recomendaciones():
    global user_id, recommended_movies, current_index, last_liked_movie_id
    user_id = random.choice(df_muestra['userId'].unique())  # Seleccionar un usuario al azar
    recommended_movies = get_top_movies_for_user(user_id)
    current_index = 0
    last_liked_movie_id = None  # Reiniciar la última película que le gustó

inicializar_recomendaciones()  # Generar la primera recomendación

liked_movies = []  # Lista para almacenar películas que le gustan
like_count = 0  # Contador de "me gusta"

def create_buttons(movie_title):
    movie_title_escaped = movie_title.replace("'", "\'").replace('"', '\"')  # Escapar caracteres
    display(Javascript(f'''
        var div = document.createElement('div');
        var btn1 = document.createElement('button');
        btn1.innerHTML = 'Me gusta: {movie_title_escaped}';
        btn1.onclick = function() {{
          google.colab.kernel.invokeFunction('notebook.callback', ['Me gusta', '{movie_title_escaped}'], {{}});
        }};

        var btn2 = document.createElement('button');
        btn2.innerHTML = 'No me gusta: {movie_title_escaped}';
        btn2.onclick = function() {{
          google.colab.kernel.invokeFunction('notebook.callback', ['No me gusta', '{movie_title_escaped}'], {{}});
        }};

        div.appendChild(btn1);
        div.appendChild(btn2);
        document.body.appendChild(div);
    '''))

def handle_choice(choice, movie_title):
    global user_id, recommended_movies, current_index, last_liked_movie_id, liked_movies, like_count

    print(f'Has elegido: {choice} para {movie_title}')

    if choice == 'Me gusta':
        # Obtener el ID de la película
        movie_id = df_muestra[df_muestra['title'] == movie_title]['movieId'].values[0]

        # Guardar la última película que le gustó
        last_liked_movie_id = movie_id
        liked_movies.append(movie_title)  # Guardar título de la película
        like_count += 1  # Incrementar el contador de "me gusta"

        # Verificar si ha alcanzado 6 "me gusta"
        if like_count >= 6:
            # Crear el mensaje final con las películas que le gustaron
            final_message = "Te gustan las siguientes películas:\n"
            final_message += ', '.join(liked_movies)

            display(HTML(final_message))
            return  # Termina el programa

        current_index += 1
        if current_index < len(recommended_movies):
            next_movie_id, next_score = recommended_movies[current_index]
            next_movie_title = df_muestra[df_muestra['movieId'] == next_movie_id]['title'].values[0]
            print(f"Película recomendada: {next_movie_title}, score: {next_score}")
            create_buttons(next_movie_title)
        else:
            print("No hay más películas en la lista de recomendaciones. Seleccionando un nuevo usuario.")
            inicializar_recomendaciones()
            next_movie_id, next_score = recommended_movies[current_index]
            next_movie_title = df_muestra[df_muestra['movieId'] == next_movie_id]['title'].values[0]
            print(f"Nuevo usuario seleccionado. Película recomendada: {next_movie_title}, score: {next_score}")
            create_buttons(next_movie_title)
    else:
        # Seleccionar una nueva película si elige 'No me gusta'
        unseen_movies = set(df_muestra['movieId']) - set(df_muestra[df_muestra['userId'] == user_id]['movieId'])
        next_movie_id = random.choice(list(unseen_movies))
        next_movie_title = df_muestra[df_muestra['movieId'] == next_movie_id]['title'].values[0]
        next_score = modelo_svd.predict(user_id, next_movie_id).est
        print(f"Nueva película recomendada: {next_movie_title}, score: {next_score}")
        create_buttons(next_movie_title)

# Registrar la función en Google Colab
from google.colab import output
output.register_callback('notebook.callback', handle_choice)

# Mostrar la primera película recomendada
first_movie_id, first_score = recommended_movies[current_index]
first_movie_title = df_muestra[df_muestra['movieId'] == first_movie_id]['title'].values[0]
print(f"Película recomendada: {first_movie_title}, score: {first_score}")
create_buttons(first_movie_title)
# Out:
# Película recomendada: Fight Club, score: 4.251210017462155
# Has elegido: Me gusta para Fight Club
# Película recomendada: WALL·E, score: 4.23046987594742
# Has elegido: Me gusta para WALL·E
# Película recomendada: Psycho, score: 4.209753064857819
# Has elegido: Me gusta para Psycho
# Película recomendada: Snatch, score: 4.192756284221192
# Has elegido: No me gusta para Snatch
# Nueva película recomendada: Herbie Goes Bananas, score: 3.2608756071437552
# Has elegido: No me gusta para Herbie Goes Bananas
# Nueva película recomendada: Marie Antoinette, score: 3.677378434376345
# Has elegido: Me gusta para Marie Antoinette
# Película recomendada: Vertigo, score: 4.186291608128982
# Has elegido: Me gusta para Vertigo
# No hay más películas en la lista de recomendaciones. Seleccionando un nuevo usuario.
# Nuevo usuario seleccionado. Película recomendada: Rear Window, score: 4.397009587570284
# Has elegido: Me gusta para Rear Window
# Te gustan las siguientes películas:
# Fight Club, WALL·E, Psycho, Marie Antoinette, Vertigo, Rear Window

# %% [markdown]
# ## Aplicación listado de películas y plataforma recomendada

# %%
import random
from IPython.display import Javascript, display, HTML
from google.colab.output import eval_js
import pandas as pd
import numpy as np
from surprise import Dataset, Reader, SVD

# Asumimos que df_muestra ya está cargado con las películas y ratings

# Convertir el DataFrame en el formato esperado por Surprise
reader = Reader(rating_scale=(0.5, 5))
data = Dataset.load_from_df(df_muestra[['userId', 'movieId', 'rating']], reader)

# Entrenar el modelo con Surprise
trainset = data.build_full_trainset()
modelo_svd = SVD()
modelo_svd.fit(trainset)

# Función para obtener recomendaciones de películas basadas en predicciones
def get_top_movies_for_user(user_id, last_liked_movie_id=None, n=5):
    # Obtener todas las películas que el usuario no ha visto
    unseen_movies = set(df_muestra['movieId']) - set(df_muestra[df_muestra['userId'] == user_id]['movieId'])

    # Predecir ratings para estas películas usando el modelo de Surprise
    predictions = [(movie_id, modelo_svd.predict(user_id, movie_id).est) for movie_id in unseen_movies]

    # Si hay una película que le gustó, filtrar por similitud
    if last_liked_movie_id is not None:
        # Filtrar las películas que tengan un score más cercano a la última película que le gustó
        similar_movies = [(movie_id, score) for movie_id, score in predictions if abs(score - modelo_svd.predict(user_id, last_liked_movie_id).est) < 0.1]
        predictions = similar_movies if similar_movies else predictions  # Si no hay similares, usar todas

    # Ordenar por rating predicho y devolver las top n
    return sorted(predictions, key=lambda x: x[1], reverse=True)[:n]

# Inicializar lista de películas recomendadas para un usuario aleatorio
def inicializar_recomendaciones():
    global user_id, recommended_movies, current_index, last_liked_movie_id
    user_id = random.choice(df_muestra['userId'].unique())  # Seleccionar un usuario al azar
    recommended_movies = get_top_movies_for_user(user_id)
    current_index = 0
    last_liked_movie_id = None  # Reiniciar la última película que le gustó

inicializar_recomendaciones()  # Generar la primera recomendación

liked_movies = []  # Lista para almacenar películas que le gustan
like_count = 0  # Contador de "me gusta"

def create_buttons(movie_title):
    movie_title_escaped = movie_title.replace("'", "\'").replace('"', '\"')  # Escapar caracteres
    display(Javascript(f'''
        var div = document.createElement('div');
        var btn1 = document.createElement('button');
        btn1.innerHTML = 'Me gusta: {movie_title_escaped}';
        btn1.onclick = function() {{
          google.colab.kernel.invokeFunction('notebook.callback', ['Me gusta', '{movie_title_escaped}'], {{}});
        }};

        var btn2 = document.createElement('button');
        btn2.innerHTML = 'No me gusta: {movie_title_escaped}';
        btn2.onclick = function() {{
          google.colab.kernel.invokeFunction('notebook.callback', ['No me gusta', '{movie_title_escaped}'], {{}});
        }};

        div.appendChild(btn1);
        div.appendChild(btn2);
        document.body.appendChild(div);
    '''))

def handle_choice(choice, movie_title):
    global user_id, recommended_movies, current_index, last_liked_movie_id, liked_movies, like_count

    print(f'Has elegido: {choice} para {movie_title}')

    if choice == 'Me gusta':
        # Obtener el ID de la película
        movie_id = df_muestra[df_muestra['title'] == movie_title]['movieId'].values[0]

        # Guardar la última película que le gustó
        last_liked_movie_id = movie_id
        liked_movies.append(movie_title)  # Guardar título de la película
        like_count += 1  # Incrementar el contador de "me gusta"

        # Verificar si ha alcanzado 6 "me gusta"
        if like_count >= 6:
            # Crear el mensaje final con las películas que le gustaron
            final_message = "<h3>Te gustan las siguientes películas:</h3>"
            final_message += '<ul>' + ''.join(f"<li>{movie}</li>" for movie in liked_movies) + '</ul>'

            # Contar la frecuencia de las plataformas
            platform_counts = {
                'Netflix': sum(df_muestra[df_muestra['title'] == movie]['netflix'].values[0] for movie in liked_movies),
                'Hulu': sum(df_muestra[df_muestra['title'] == movie]['hulu'].values[0] for movie in liked_movies),
                'Prime Video': sum(df_muestra[df_muestra['title'] == movie]['prime video'].values[0] for movie in liked_movies),
                'Disney+': sum(df_muestra[df_muestra['title'] == movie]['disney+'].values[0] for movie in liked_movies)
            }

            # Determinar la plataforma más frecuente
            best_platform = max(platform_counts, key=platform_counts.get)

            # Resaltar en rojo la mejor plataforma
            final_message += f"<h4 style='color: red;'>La plataforma que más se ajusta a tus gustos es: {best_platform}</h4>"

            display(HTML(final_message))
            return  # Termina el programa

        current_index += 1
        if current_index < len(recommended_movies):
            next_movie_id, next_score = recommended_movies[current_index]
            next_movie_title = df_muestra[df_muestra['movieId'] == next_movie_id]['title'].values[0]
            print(f"Película recomendada: {next_movie_title}, score: {next_score}")
            create_buttons(next_movie_title)
        else:
            print("No hay más películas en la lista de recomendaciones. Seleccionando un nuevo usuario.")
            inicializar_recomendaciones()
            next_movie_id, next_score = recommended_movies[current_index]
            next_movie_title = df_muestra[df_muestra['movieId'] == next_movie_id]['title'].values[0]
            print(f"Nuevo usuario seleccionado. Película recomendada: {next_movie_title}, score: {next_score}")
            create_buttons(next_movie_title)
    else:
        # Seleccionar una nueva película si elige 'No me gusta'
        unseen_movies = set(df_muestra['movieId']) - set(df_muestra[df_muestra['userId'] == user_id]['movieId'])
        next_movie_id = random.choice(list(unseen_movies))
        next_movie_title = df_muestra[df_muestra['movieId'] == next_movie_id]['title'].values[0]
        next_score = modelo_svd.predict(user_id, next_movie_id).est
        print(f"Nueva película recomendada: {next_movie_title}, score: {next_score}")
        create_buttons(next_movie_title)

# Registrar la función en Google Colab
from google.colab import output
output.register_callback('notebook.callback', handle_choice)

# Mostrar la primera película recomendada
first_movie_id, first_score = recommended_movies[current_index]
first_movie_title = df_muestra[df_muestra['movieId'] == first_movie_id]['title'].values[0]
print(f"Película recomendada: {first_movie_title}, score: {first_score}")
create_buttons(first_movie_title)
# Out:
# Película recomendada: WALL·E, score: 4.2352934466084955
# Has elegido: Me gusta para WALL·E
# Película recomendada: Psycho, score: 4.223317828911326
# Has elegido: Me gusta para Psycho
# Película recomendada: Snatch, score: 4.108577057553384
# Has elegido: No me gusta para Snatch
# Nueva película recomendada: Sinbad: Legend of the Seven Seas, score: 3.5360469126393177
# Has elegido: No me gusta para Sinbad: Legend of the Seven Seas
# Nueva película recomendada: Searching for Bobby Fischer, score: 3.6930353890008147
# Has elegido: No me gusta para Searching for Bobby Fischer
# Nueva película recomendada: Zombieland, score: 3.94176110064838
# Has elegido: Me gusta para Zombieland
# Película recomendada: Terminator 2: Judgment Day, score: 4.0999366342117485
# Has elegido: Me gusta para Terminator 2: Judgment Day
# Película recomendada: Rear Window, score: 4.095488435651939
# Has elegido: Me gusta para Rear Window
# No hay más películas en la lista de recomendaciones. Seleccionando un nuevo usuario.
# Nuevo usuario seleccionado. Película recomendada: Rear Window, score: 4.4728529023479195
# Has elegido: Me gusta para Rear Window
# <h3>Te gustan las siguientes películas:</h3><ul><li>WALL·E</li><li>Psycho</li><li>Zombieland</li><li>Terminator 2: Judgment Day</li><li>Rear Window</li><li>Rear Window</li></ul><h4 style='color: red;'>La plataforma que más se ajusta a tus gustos es: Netflix</h4>
