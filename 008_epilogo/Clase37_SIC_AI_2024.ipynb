# %% [markdown]
# <a href="https://colab.research.google.com/github/davidlealo/sic_ai_2024/blob/main/008_epilogo/Clase37_SIC_AI_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase 37 SIC AI Chapter 2 Quiz
#
# # AI Course
#
# ## Chapter 2. Quiz
#
#
# 1. Create examples of zero vector, one vector, square matrix, diagonal matrix, identity matrix, and symmetric matrix one by one, and represent vectors and matrices with NumPy.
#
# 2. The shares of three companies A, B, and C are 1 million won, 800,000 won, and 500,000 won, respectively. We want to find the amount required to purchase 3, 4, and 5 shares of these stocks, respectively.
#
#    1) Express the stocks' price and quantity as p vector and n vector, respectively and coded with NumPy.
#
#    2) The amount required to purchase stocks is expressed by multiplication, and the value is calculated by Numpy operation.
#
# 3. When the following code is executed, all data of the MNIST numeric image is converted into vectors to create a single NumPy matrix X. Use this matrix to solve the following problem.
#
#    ```python
#    from sklearn.datasets import load_digits
#    X=load_digits().data
#    ```
#
#    1) Find the similarity between the first image and the tenth image using dot product.
#
#    2) Find the similarity for a combination of all images using the dot product, how would it be efficient to implement it (hint: using matrices and multiplication of matrices)
#
# 4. Calculate the following inverse matrix.
#
#    $$\begin{bmatrix}
#    2 & 0 \\
#    0 & 1
#    \end{bmatrix}^{- 1}$$
#
# 5. The Boston house price problem is a problem of predicting the housing price of each town in Boston, USA using features such as the crime rate and air pollution in the area. It can be imported from the load_boston function. Find the weight vector x when the Boston house price problem is solved with the linear prediction model Ax=$\widehat{b}$. Matrix and vector data can be obtained as follows.
#
#    Here, to simplify the problem, we limited the input data to crime rate (CRIM), air quality (NOX), number of rooms (RM), and age (AGE), and only four data were used.
#
#    Run the code below to check whether the magnitude or sign of the weight vector obtained from running the program is consistent the common notion. In order to find it, interpret the printed output for all the factors: CRIM, NOX, RM and AGE.
#    ※ Write the interpreted output like *"the house price is in inverse proportion to the crime rate (CRIM)."*
#
#    ```python
#    import pandas as pd
#    import numpy as np
#
#    def load_boston():
#        data_url = "http://lib.stat.cmu.edu/datasets/boston"
#        raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#        data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#        target = raw_df.values[1::2, 2]
#        return {'data': data, 'target': target}
#
#    boston=load_boston()
#    X=boston['data']
#    y=boston['target']
#    A=X[:4, [0,4,5,6]] # 'CRIM','NOX','RM','AGE'
#    b=y[:4]
#    ```
#
# 6. Find the weight vector w when the Boston house price problem is solved with the linear prediction model X_w = y ̂ by the least-squares method. Matrix and vector data can be obtained as follows.
#
#    ※ This question is related to Question 5.
#
#    ```python
#    import pandas as pd
#    import numpy as np
#
#    def load_boston():
#        data_url = "http://lib.stat.cmu.edu/datasets/boston"
#        raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#        data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#        target = raw_df.values[1::2, 2]
#        return {'data': data, 'target': target}
#
#    boston=load_boston()
#    X=boston['data']
#    y=boston['target']
#    ```
#
#    The meaning of each column of matrix X is as follows.
#
#    - CRIM: crime rate
#    - INDUS: Non-retail commercial area ratio
#    - NOX: Nitric Oxide Concentration
#    - RM: Number of rooms per house
#    - LSTAT: Proportion of the lower class of the population
#    - B: Proportion of black people in the population
#    - PTRATIO: Student/Teacher Ratio
#    - ZN: Percentage of residential areas exceeding 25,000 square feet
#    - CHAS: 1 if located on the Charles River border, 0 otherwise
#    - AGE: Percentage of houses built before 1940
#    - RAD: Distance to radial highway
#    - DIS: Weighted average distance to 5 Boston Job Centers
#    - TAX: property tax rate
#
#    1) Run the program above to check whether the magnitude or sign of the weight vector obtained from running the program is consistent the common notion. In order to find it, interpret the printed output for all the factors suggested above.
#
#    ※ Write the interpreted output like *"the house price is in inverse proportion to the crime rate (CRIM)".*
#
#    2) Explain how the result differs from the value obtained in Question 5.
#
# 7. The ratings given by three users a, b, and c to 4 movies are expressed as vectors as follows.
#
#    a = $\begin{pmatrix}
#    4 \\
#    5 \\
#    \begin{matrix}
#    2 \\
#    2
#    \end{matrix}
#    \end{pmatrix},\ b$ = $\begin{pmatrix}
#    4 \\
#    0 \\
#    \begin{matrix}
#    2 \\
#    0
#    \end{matrix}
#    \end{pmatrix}$, c = $\begin{pmatrix}
#    2 \\
#    2 \\
#    \begin{matrix}
#    0 \\
#    1
#    \end{matrix}
#    \end{pmatrix}$
#
#    1) Find the Euclidean distance between a, b, and c. Which two users are the closest? And which two users are farthest apart?
#
#    2) Find the cosine distance between a, b, and c. Which two users are the closest? And which two users are farthest apart?
#
# 8. Find the eigenvalues of the following matrix using the characteristic equation.
#
#    D=$\begin{bmatrix}
#    2 & 1 \\
#    1 & 2
#    \end{bmatrix}$
#
# 9. The $\log 2$ value is about 0.69, and the $\log 3$ value is about 1.10. At this time, find the $\log 12$ value.
#
# 10. Find the inverse function of the logistic function.
#
#     y = $\sigma(x)$ = $\frac{1}{1 + exp( - x)}$
#
# 11. Differentiate the following functions. In this equation, k, a, and b are constants, not variables.
#
#     A. f(x) = $x^{3} - 1$
#
#     B. f(x) = $\log\left( x^{2} - 3k \right)$
#
#     C. f(x) =exp(${ax}^{b})$
#
# 12. Find the first/second partial derivatives $f_{x},\ f_{y},\ f_{xx},\ f_{xy},\ f_{yx},\ f_{yy}$ for the following function.
#
#     f(x,y) = exp($x^{2} + 2\ y^{2})$
#
# 13. Find the derivative that differentiates the following function using SymPy. In this expression, k, a, and b are constants, not variables.
#
#     A. f(x) = $x^{3} - 1$
#
#     B. f(x) = $\log\left( x^{2} - 3k \right)$
#
#     C. f(x) =exp(${ax}^{b})$
#
# 14. Find the first/second partial derivatives $f_{x},\ f_{y},\ f_{xx},\ f_{xy},\ f_{yx},\ f_{yy}$ for the following function using SymPy.
#
#     f(x,y) = exp($x^{2} + 2\ y^{2})$

# %% [markdown]
# ### Respuestas
#
# 4. Calculate the following inverse matrix.
#
#    $$\begin{bmatrix}
#    2 & 0 \\
#    0 & 1
#    \end{bmatrix}^{- 1}$$

# %%
import numpy as np

# %%
matriz = np.array([[2, 0],
              [0, 1]])

# %%
np.linalg.inv(matriz)
# Out:
# array([[0.5, 0. ],
#        [0. , 1. ]])

# %% [markdown]
# 5. The Boston house price problem is a problem of predicting the housing price of each town in Boston, USA using features such as the crime rate and air pollution in the area. It can be imported from the load_boston function. Find the weight vector x when the Boston house price problem is solved with the linear prediction model Ax=$\widehat{b}$. Matrix and vector data can be obtained as follows.
#
#    Here, to simplify the problem, we limited the input data to crime rate (CRIM), air quality (NOX), number of rooms (RM), and age (AGE), and only four data were used.
#
#    Run the code below to check whether the magnitude or sign of the weight vector obtained from running the program is consistent the common notion. In order to find it, interpret the printed output for all the factors: CRIM, NOX, RM and AGE.
#    ※ Write the interpreted output like *"the house price is in inverse proportion to the crime rate (CRIM)."*
#
#    ```python
#    import pandas as pd
#    import numpy as np
#
#    def load_boston():
#        data_url = "http://lib.stat.cmu.edu/datasets/boston"
#        raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#        data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#        target = raw_df.values[1::2, 2]
#        return {'data': data, 'target': target}
#
#    boston=load_boston()
#    X=boston['data']
#    y=boston['target']
#    A=X[:4, [0,4,5,6]] # 'CRIM','NOX','RM','AGE'
#    b=y[:4]
#    ```

# %% [markdown]
# #### Traducción de Google
#
# El problema del precio de la vivienda en Boston es un problema de predicción del precio de la vivienda en cada ciudad de Boston, EE. UU., utilizando características como la tasa de criminalidad y la contaminación del aire en el área. Se puede importar desde la función load_boston. Encuentre el vector de peso x cuando el problema del precio de la vivienda en Boston se resuelve con el modelo de predicción lineal Ax= 𝑏ˆ . Los datos de matriz y vector se pueden obtener de la siguiente manera.
#
# Aquí, para simplificar el problema, limitamos los datos de entrada a la tasa de criminalidad (CRIM), la calidad del aire (NOX), la cantidad de habitaciones (RM) y la edad (AGE), y solo se utilizaron cuatro datos.
#
# Ejecute el código a continuación para verificar si la magnitud o el signo del vector de peso obtenido al ejecutar el programa es consistente con la noción común. Para encontrarlo, interprete la salida impresa para todos los factores: CRIM, NOX, RM y AGE. ※ Escriba la salida interpretada como *"el precio de la vivienda es inversamente proporcional a la tasa de criminalidad (CRIM)".*

# %%
import pandas as pd
import numpy as np

def load_boston():
    data_url = "http://lib.stat.cmu.edu/datasets/boston"
    raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
    data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
    target = raw_df.values[1::2, 2]
    return {'data': data, 'target': target}

boston=load_boston()
X=boston['data']
y=boston['target']
A=X[:4, [0,4,5,6]] # 'CRIM','NOX','RM','AGE'
b=y[:4]

# %%
A
# Out:
# array([[6.320e-03, 5.380e-01, 6.575e+00, 6.520e+01],
#        [2.731e-02, 4.690e-01, 6.421e+00, 7.890e+01],
#        [2.729e-02, 4.690e-01, 7.185e+00, 6.110e+01],
#        [3.237e-02, 4.580e-01, 6.998e+00, 4.580e+01]])

# %%
b
# Out:
# array([24. , 21.6, 34.7, 33.4])

# %%
columns = ['Crimen','Aire','Habitaciones','Antiguedad']

# %%
df = pd.DataFrame(data = A, columns = columns)
print(df)
# Out:
#     Crimen   Aire  Habitaciones  Antiguedad
# 0  0.00632  0.538         6.575        65.2
# 1  0.02731  0.469         6.421        78.9
# 2  0.02729  0.469         7.185        61.1
# 3  0.03237  0.458         6.998        45.8

# %%
df.corr()
# Out:
#                 Crimen      Aire  Habitaciones  Antiguedad
# Crimen        1.000000 -0.997819      0.454497   -0.289687
# Aire         -0.997819  1.000000     -0.443070    0.236988
# Habitaciones  0.454497 -0.443070      1.000000   -0.731532
# Antiguedad   -0.289687  0.236988     -0.731532    1.000000

# %%
column_price = ['Price']

# %%
price = pd.DataFrame(data = b, columns = column_price)
print(price)
# Out:
#    Price
# 0   24.0
# 1   21.6
# 2   34.7
# 3   33.4

# %%
new_df = pd.concat([df, price], axis=1)

print(new_df)
# Out:
#     Crimen   Aire  Habitaciones  Antiguedad  Price
# 0  0.00632  0.538         6.575        65.2   24.0
# 1  0.02731  0.469         6.421        78.9   21.6
# 2  0.02729  0.469         7.185        61.1   34.7
# 3  0.03237  0.458         6.998        45.8   33.4

# %%
new_df.corr()
# Out:
#                 Crimen      Aire  Habitaciones  Antiguedad     Price
# Crimen        1.000000 -0.997819      0.454497   -0.289687  0.514921
# Aire         -0.997819  1.000000     -0.443070    0.236988 -0.496212
# Habitaciones  0.454497 -0.443070      1.000000   -0.731532  0.990397
# Antiguedad   -0.289687  0.236988     -0.731532    1.000000 -0.800977
# Price         0.514921 -0.496212      0.990397   -0.800977  1.000000

# %%
new_df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_43028_row0_col0, #T_43028_row1_col1, #T_43028_row2_col2, #T_43028_row3_col3, #T_43028_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_43028_row0_col1, #T_43028_row1_col0, #T_43028_row3_col2, #T_43028_row3_col4, #T_43028_row4_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_43028_row0_col2 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_43028_row0_col3 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_43028_row0_col4 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_43028_row1_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_43028_row1_col3 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_43028_row1_col4 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_43028_row2_col0 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_43028_row2_col1 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_43028_row2_col3 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_43028_row2_col4, #T_43028_row4_col2 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_43028_row3_col0 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_43028_row3_col1 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_43028_row4_col0 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_43028_row4_col1 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# </style>
# <table id="T_43028" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43028_level0_col0" class="col_heading level0 col0" >Crimen</th>
#       <th id="T_43028_level0_col1" class="col_heading level0 col1" >Aire</th>
#       <th id="T_43028_level0_col2" class="col_heading level0 col2" >Habitaciones</th>
#       <th id="T_43028_level0_col3" class="col_heading level0 col3" >Antiguedad</th>
#       <th id="T_43028_level0_col4" class="col_heading level0 col4" >Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43028_level0_row0" class="row_heading level0 row0" >Crimen</th>
#       <td id="T_43028_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_43028_row0_col1" class="data row0 col1" >-0.997819</td>
#       <td id="T_43028_row0_col2" class="data row0 col2" >0.454497</td>
#       <td id="T_43028_row0_col3" class="data row0 col3" >-0.289687</td>
#       <td id="T_43028_row0_col4" class="data row0 col4" >0.514921</td>
#     </tr>
#     <tr>
#       <th id="T_43028_level0_row1" class="row_heading level0 row1" >Aire</th>
#       <td id="T_43028_row1_col0" class="data row1 col0" >-0.997819</td>
#       <td id="T_43028_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_43028_row1_col2" class="data row1 col2" >-0.443070</td>
#       <td id="T_43028_row1_col3" class="data row1 col3" >0.236988</td>
#       <td id="T_43028_row1_col4" class="data row1 col4" >-0.496212</td>
#     </tr>
#     <tr>
#       <th id="T_43028_level0_row2" class="row_heading level0 row2" >Habitaciones</th>
#       <td id="T_43028_row2_col0" class="data row2 col0" >0.454497</td>
#       <td id="T_43028_row2_col1" class="data row2 col1" >-0.443070</td>
#       <td id="T_43028_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_43028_row2_col3" class="data row2 col3" >-0.731532</td>
#       <td id="T_43028_row2_col4" class="data row2 col4" >0.990397</td>
#     </tr>
#     <tr>
#       <th id="T_43028_level0_row3" class="row_heading level0 row3" >Antiguedad</th>
#       <td id="T_43028_row3_col0" class="data row3 col0" >-0.289687</td>
#       <td id="T_43028_row3_col1" class="data row3 col1" >0.236988</td>
#       <td id="T_43028_row3_col2" class="data row3 col2" >-0.731532</td>
#       <td id="T_43028_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_43028_row3_col4" class="data row3 col4" >-0.800977</td>
#     </tr>
#     <tr>
#       <th id="T_43028_level0_row4" class="row_heading level0 row4" >Price</th>
#       <td id="T_43028_row4_col0" class="data row4 col0" >0.514921</td>
#       <td id="T_43028_row4_col1" class="data row4 col1" >-0.496212</td>
#       <td id="T_43028_row4_col2" class="data row4 col2" >0.990397</td>
#       <td id="T_43028_row4_col3" class="data row4 col3" >-0.800977</td>
#       <td id="T_43028_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Interpretación del resultado
print("Interpretación:")
print(f"El precio de la casa es proporcional a la tasa de criminalidad (CRIM): 0.51")
print(f"El precio de la casa es inversamente proporcional a la calidad del aire (NOX): -0.5")
print(f"El precio de la casa es proporcional al número de habitaciones (RM): 0.99")
print(f"El precio de la casa es inversamente proporcional a la antigüedad de la casa (AGE): -0.8")
# Out:
# Interpretación:
# El precio de la casa es proporcional a la tasa de criminalidad (CRIM): 0.51
# El precio de la casa es inversamente proporcional a la calidad del aire (NOX): -0.5
# El precio de la casa es proporcional al número de habitaciones (RM): 0.99
# El precio de la casa es inversamente proporcional a la antigüedad de la casa (AGE): -0.8

# %%
# Resolver la ecuación Ax = b usando la fórmula de mínimos cuadrados
x = np.linalg.inv(A.T @ A) @ A.T @ b

# Imprimir el vector de pesos
print("Vector de pesos:", x)

# Interpretación del resultado
print("Interpretación:")
print(f"El precio de la casa es inversamente proporcional a la tasa de criminalidad (CRIM): {x[0]}")
print(f"El precio de la casa es inversamente proporcional a la calidad del aire (NOX): {x[1]}")
print(f"El precio de la casa es proporcional al número de habitaciones (RM): {x[2]}")
print(f"El precio de la casa es inversamente proporcional a la antigüedad de la casa (AGE): {x[3]}")
# Out:
# Vector de pesos: [-3.12710043e+02 -1.15193942e+02  1.44996465e+01 -1.13259317e-01]
# Interpretación:
# El precio de la casa es inversamente proporcional a la tasa de criminalidad (CRIM): -312.71004327038827
# El precio de la casa es inversamente proporcional a la calidad del aire (NOX): -115.19394234556876
# El precio de la casa es proporcional al número de habitaciones (RM): 14.499646531806263
# El precio de la casa es inversamente proporcional a la antigüedad de la casa (AGE): -0.11325931735030914

# %% [markdown]
# 6. Find the weight vector w when the Boston house price problem is solved with the linear prediction model X_w = y ̂ by the least-squares method. Matrix and vector data can be obtained as follows.
#
#    ※ This question is related to Question 5.
#
#    ```python
#    import pandas as pd
#    import numpy as np
#
#    def load_boston():
#        data_url = "http://lib.stat.cmu.edu/datasets/boston"
#        raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#        data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#        target = raw_df.values[1::2, 2]
#        return {'data': data, 'target': target}
#
#    boston=load_boston()
#    X=boston['data']
#    y=boston['target']
#    ```
#
#    The meaning of each column of matrix X is as follows.
#
#    - CRIM: crime rate
#    - INDUS: Non-retail commercial area ratio
#    - NOX: Nitric Oxide Concentration
#    - RM: Number of rooms per house
#    - LSTAT: Proportion of the lower class of the population
#    - B: Proportion of black people in the population
#    - PTRATIO: Student/Teacher Ratio
#    - ZN: Percentage of residential areas exceeding 25,000 square feet
#    - CHAS: 1 if located on the Charles River border, 0 otherwise
#    - AGE: Percentage of houses built before 1940
#    - RAD: Distance to radial highway
#    - DIS: Weighted average distance to 5 Boston Job Centers
#    - TAX: property tax rate
#
#    1) Run the program above to check whether the magnitude or sign of the weight vector obtained from running the program is consistent the common notion. In order to find it, interpret the printed output for all the factors suggested above.
#
#    ※ Write the interpreted output like *"the house price is in inverse proportion to the crime rate (CRIM)".*
#
#    2) Explain how the result differs from the value obtained in Question 5.

# %% [markdown]
# #### Traducción de Google
#
# 6. Halla el vector de ponderación w cuando el problema del precio de la vivienda en Boston se resuelve con el modelo de predicción lineal X_w = y ̂ por el método de mínimos cuadrados. Los datos matriciales y vectoriales se pueden obtener de la siguiente manera.
#
# ※ Esta pregunta está relacionada con la pregunta 5.
#
# ```python
# import pandas as pd
# import numpy as np
#
# def load_boston():
# data_url = "http://lib.stat.cmu.edu/datasets/boston"
# raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
# data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
# target = raw_df.values[1::2, 2]
# return {'data': data, 'target': target}
#
# boston=load_boston()
# X=boston['data']
# y=boston['target']
# ```
#
# El significado de cada columna de la matriz X es el siguiente.
#
# - CRIM: índice de criminalidad
# - INDUS: índice de área comercial no minorista
# - NOX: concentración de óxido nítrico
# - RM: número de habitaciones por casa
# - LSTAT: proporción de la clase baja de la población
# - B: proporción de personas de raza negra en la población
# - PTRATIO: índice de alumnos por docente
# - ZN: porcentaje de áreas residenciales que superan los 25 000 pies cuadrados
# - CHAS: 1 si se encuentra en la frontera del río Charles, 0 en caso contrario
# - AGE: porcentaje de casas construidas antes de 1940
# - RAD: distancia a la autopista radial
# - DIS: distancia promedio ponderada a 5 centros de empleo de Boston
# - TAX: tasa de impuesto a la propiedad
#
# 1) Ejecute el programa anterior para verificar si la magnitud o el signo del vector de peso obtenido al ejecutar el programa es consistente con la noción común. Para encontrarlo, interprete la salida impresa para todos los factores sugeridos anteriormente.
#
# ※ Escriba el resultado interpretado como *"el precio de la vivienda es inversamente proporcional a la tasa de criminalidad (CRIM)".*
#
# 2) Explique en qué se diferencia el resultado del valor obtenido en la pregunta 5.

# %%
import pandas as pd
import numpy as np

# Función para cargar el conjunto de datos de Boston
def load_boston():
    data_url = "http://lib.stat.cmu.edu/datasets/boston"
    raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
    # Unir las filas pares e impares en una única matriz de datos
    data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
    # El objetivo (precios de las casas) está en la tercera columna de las filas impares
    target = raw_df.values[1::2, 2]
    return {'data': data, 'target': target}

# Cargar los datos de Boston
boston = load_boston()

# Matriz de características (X)
X = boston['data']

# Vector objetivo (precios de las casas, y)
y = boston['target']

# Resolver el problema de mínimos cuadrados
w = np.linalg.inv(X.T @ X) @ X.T @ y

# Imprimir el vector de pesos (w)
print("Vector de pesos (w):", w)

# Interpretación del resultado
print("\nInterpretación:")
columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']
for i, coef in enumerate(w):
    print(f"El coeficiente de {columns[i]} es {coef:.4f}")
# Out:
# Vector de pesos (w): [-9.28965170e-02  4.87149552e-02 -4.05997958e-03  2.85399882e+00
#  -2.86843637e+00  5.92814778e+00 -7.26933458e-03 -9.68514157e-01
#   1.71151128e-01 -9.39621540e-03 -3.92190926e-01  1.49056102e-02
#  -4.16304471e-01]
#
# Interpretación:
# El coeficiente de CRIM es -0.0929
# El coeficiente de ZN es 0.0487
# El coeficiente de INDUS es -0.0041
# El coeficiente de CHAS es 2.8540
# El coeficiente de NOX es -2.8684
# El coeficiente de RM es 5.9281
# El coeficiente de AGE es -0.0073
# El coeficiente de DIS es -0.9685
# El coeficiente de RAD es 0.1712
# El coeficiente de TAX es -0.0094
# El coeficiente de PTRATIO es -0.3922
# El coeficiente de B es 0.0149
# El coeficiente de LSTAT es -0.4163
